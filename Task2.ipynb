# %% [markdown]
# Opening CSV as pandas dataframe

# %%
import pandas as pd
pd.options.display.max_rows = 995000

data = pd.read_csv("995,000_rows.csv", header = 0,sep=",",nrows=1000) #Increase nrows to heat up PC
data.info()
data[:500]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   id                1000 non-null   float64
#  2   domain            1000 non-null   object
#  3   type              951 non-null    object
#  4   url               1000 non-null   object
#  5   content           1000 non-null   object
#  6   scraped_at        1000 non-null   object
#  7   inserted_at       1000 non-null   object
#  8   updated_at        1000 non-null   object
#  9   title             992 non-null    object
#  10  authors           563 non-null    object
#  11  keywords          0 non-null      float64
#  12  meta_keywords     968 non-null    object
#  13  meta_description  467 non-null    object
#  14  tags              219 non-null    object
#  15  summary           0 non-null      float64
# ...

# %% [markdown]
# What is the unnamed column 0?

# %%
data.keys()
# Out:
# Index(['Unnamed: 0', 'id', 'domain', 'type', 'url', 'content', 'scraped_at',
#        'inserted_at', 'updated_at', 'title', 'authors', 'keywords',
#        'meta_keywords', 'meta_description', 'tags', 'summary', 'source'],
#       dtype='object')
